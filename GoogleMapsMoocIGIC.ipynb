# %%
import pandas as pd

# %%
df_librerias=pd.read_csv('dataset.csv')
df_librerias.head()
# Out:
#                                             Nombre    Latitud   Longitud
# 0  Fondo de Cultura Económica Librería Octavio Paz  19.347358 -99.182665
# 1                                 Librerías Gandhi  19.348507 -99.163252
# 2                              Librerías El Sótano  19.346378 -99.179898
# 3                                 Librerías Gandhi  19.347331 -99.182263
# 4                                    Librería Novo  19.343164 -99.181174

# %% [markdown]
# ##Creación de archivo con extensión .js

# %% [markdown]
# ###Qué es un archivo geojson? 🗺
# Formato para codificar varias estructuras de datos geográficos basado on JavaScript Object Notation (JSON). Usa una coordenada geográfica del sistema de referencia WGS 1984 y unidades de grados decimales. Soporta geometrías de tipo: Point, LineString, Polygon, MultiPoint, MultiLineString, and MultiPolygon.

# %%
tamaño = len(df_librerias)
i=1

# %%
jsfile=""
jsfile= "var libreriasData = { 'type':'FeatureCollection',\n"
jsfile = jsfile + "'features':[\n"
for index, row in df_librerias.iterrows():
  nombre=row['Nombre']
  longitud=row['Longitud']
  latitud=row['Latitud']
  if i < tamaño:
    jsfile = jsfile + " {'type':'Feature', \n 'properties':{'nombre':'"+nombre+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}},\n"
    i+=1
  else:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'nombre':'"+nombre+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}} \n]};"

# %%
print(jsfile)
# Out:
# var libreriasData = { 'type':'FeatureCollection',
# 'features':[
#  {'type':'Feature',
#  'properties':{'nombre':'Fondo de Cultura Económica Librería Octavio Paz'},
#  'geometry': {'type':'Point', 'coordinates':[-99.18266544,19.34735833]}}
# ]}; {'type':'Feature',
#  'properties':{'nombre':'Librerías Gandhi'},
#  'geometry': {'type':'Point', 'coordinates':[-99.16325155,19.34850661]}}
# ]}; {'type':'Feature',
#  'properties':{'nombre':'Librerías El Sótano'},
#  'geometry': {'type':'Point', 'coordinates':[-99.17989794,19.34637799]}}
# ]}; {'type':'Feature',
#  'properties':{'nombre':'Librerías Gandhi'},
#  'geometry': {'type':'Point', 'coordinates':[-99.18226296,19.34733084]}}
# ]}; {'type':'Feature',
#  'properties':{'nombre':'Librería Novo'},
#  'geometry': {'type':'Point', 'coordinates':[-99.18117382,19.34316372]}}
# ]}; {'type':'Feature',
#  'properties':{'nombre':'U-Tópicas: Libros y café'},
#  'geometry': {'type':'Point', 'coordinates':[-99.1636287,19.34631048]}}
# ...

# %% [markdown]
# ###Generar archivo *.js y guardar el código en él

# %%
with open('librerias.js', 'a') as archivo:
  archivo.write(jsfile)
  archivo.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'
